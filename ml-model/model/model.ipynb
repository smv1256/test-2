# %% [markdown]
# # Exoplanet Classifier
#
# This is a Random Forest binary classifier that identifies exoplanets. I made this for the NASA Space Apps Challenge to learn more about ML.
#
# ### Table of Contents:
# 1. Get and Clean Data
# 2. Split Data into Training and Test Sets
# 3. Train Model
# 4. Summary Statistics
# 5. Save Model

# %% [markdown]
# ## Get and Clean Data

# %%
# get data
import pandas as pd

data = pd.read_csv("data.csv", comment="#")
data
# Out:
#          kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0     10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1     10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2     10811496  K00753.01           NaN       CANDIDATE        CANDIDATE
# 3     10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4     10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
# ...        ...        ...           ...             ...              ...
# 9559  10090151  K07985.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9560  10128825  K07986.01           NaN       CANDIDATE        CANDIDATE
# 9561  10147276  K07987.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9562  10155286  K07988.01           NaN       CANDIDATE        CANDIDATE
# 9563  10156110  K07989.01           NaN  FALSE POSITIVE   FALSE POSITIVE
#
#       koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0         1.000              0              0              0              0
# 1         0.969              0              0              0              0
# 2         0.000              0              0              0              0
# 3         0.000              0              1              0              0
# 4         1.000              0              0              0              0
# ...         ...            ...            ...            ...            ...
# 9559      0.000              0              1              1              0
# 9560      0.497              0              0              0              0
# 9561      0.021              0              0              1              0
# 9562      0.092              0              0              0              0
# 9563      0.000              0              0              1              1
#
#       ...  koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  \
# 0     ...           -81.0      4.467           0.064          -0.096
# 1     ...           -81.0      4.467           0.064          -0.096
# 2     ...          -176.0      4.544           0.044          -0.176
# 3     ...          -174.0      4.564           0.053          -0.168
# 4     ...          -211.0      4.438           0.070          -0.210
# ...   ...             ...        ...             ...             ...
# 9559  ...          -166.0      4.529           0.035          -0.196
# 9560  ...          -220.0      4.444           0.056          -0.224
# 9561  ...          -236.0      4.447           0.056          -0.224
# 9562  ...          -128.0      2.992           0.030          -0.027
# 9563  ...          -225.0      4.385           0.054          -0.216
#
#       koi_srad  koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag
# 0        0.927          0.105         -0.061  291.93423  48.141651      15.347
# 1        0.927          0.105         -0.061  291.93423  48.141651      15.347
# 2        0.868          0.233         -0.078  297.00482  48.134129      15.436
# 3        0.791          0.201         -0.067  285.53461  48.285210      15.597
# 4        1.046          0.334         -0.133  288.75488  48.226200      15.509
# ...        ...            ...            ...        ...        ...         ...
# 9559     0.903          0.237         -0.079  297.18875  47.093819      14.082
# 9560     1.031          0.341         -0.114  286.50937  47.163219      14.757
# 9561     1.041          0.341         -0.114  294.16489  47.176281      15.385
# 9562     7.824          0.223         -1.896  296.76288  47.145142      10.998
# 9563     1.193          0.410         -0.137  297.00977  47.121021      14.826
#
# [9564 rows x 49 columns]

# %%
# clean data
data["target"] = data["koi_disposition"].map({"CONFIRMED": 1, "CANDIDATE": 1, "FALSE POSITIVE": 0})
features = ["koi_period", "koi_impact", "koi_duration", "koi_depth", "koi_prad", "koi_model_snr", "koi_steff", "koi_slogg", "koi_srad", "koi_fpflag_nt", "koi_fpflag_co", "koi_fpflag_ss", "koi_fpflag_ec"]

y = data["target"]
x = data[features]

# average if value n/a
x.fillna(x.median())

x
# Out:
#       koi_period  koi_impact  koi_duration  koi_depth  koi_prad  \
# 0       9.488036       0.146       2.95750      615.8      2.26
# 1      54.418383       0.586       4.50700      874.8      2.83
# 2      19.899140       0.969       1.78220    10829.0     14.60
# 3       1.736952       1.276       2.40641     8079.2     33.46
# 4       2.525592       0.701       1.65450      603.3      2.75
# ...          ...         ...           ...        ...       ...
# 9559    0.527699       1.252       3.22210     1579.2     29.35
# 9560    1.739849       0.043       3.11400       48.5      0.72
# 9561    0.681402       0.147       0.86500      103.6      1.07
# 9562  333.486169       0.214       3.19900      639.1     19.30
# 9563    4.856035       0.134       3.07800       76.7      1.05
#
#       koi_model_snr  koi_steff  koi_slogg  koi_srad  koi_fpflag_nt  \
# 0              35.8     5455.0      4.467     0.927              0
# 1              25.8     5455.0      4.467     0.927              0
# 2              76.3     5853.0      4.544     0.868              0
# 3             505.6     5805.0      4.564     0.791              0
# 4              40.9     6031.0      4.438     1.046              0
# ...             ...        ...        ...       ...            ...
# 9559          453.3     5638.0      4.529     0.903              0
# 9560           10.6     6119.0      4.444     1.031              0
# 9561           12.3     6173.0      4.447     1.041              0
# 9562           14.0     4989.0      2.992     7.824              0
# 9563            8.2     6469.0      4.385     1.193              0
#
#       koi_fpflag_co  koi_fpflag_ss  koi_fpflag_ec
# 0                 0              0              0
# 1                 0              0              0
# 2                 0              0              0
# 3                 0              1              0
# 4                 0              0              0
# ...             ...            ...            ...
# 9559              1              1              0
# 9560              0              0              0
# 9561              1              0              0
# 9562              0              0              0
# 9563              1              0              1
#
# [9564 rows x 13 columns]

# %% [markdown]
# ## Split Data

# %%
# split data into training and testing datasets
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 1, stratify = y)

# %%
x_train
# Out:
#       koi_period  koi_impact  koi_duration  koi_depth  koi_prad  \
# 4480    2.150523      0.0303       3.44700      115.5      1.17
# 4603    1.381257      0.3510       1.12500       92.3      1.10
# 8971    3.093832      0.3560       1.57600      373.7      1.32
# 8938    7.448376      0.3500       4.23892   152670.0     34.37
# 9361  185.830130      0.0370      10.14000       72.6      1.01
# ...          ...         ...           ...        ...       ...
# 6960    1.807743      0.9062       2.63700      592.6      5.29
# 6725   77.395279      0.1748       5.26000      437.0      6.16
# 8920    6.208918      0.6977       2.29200     1664.0      9.20
# 7816   13.153841      0.3900      11.56000      104.6      1.03
# 8468    5.403462      0.5210       7.64940   261350.0    108.46
#
#       koi_model_snr  koi_steff  koi_slogg  koi_srad  koi_fpflag_nt  \
# 4480           11.0     5780.0      4.438     1.000              0
# 4603           11.0     5861.0      4.385     1.131              1
# 8971            9.7     5327.0      4.646     0.681              0
# 8938         1837.9     5636.0      4.489     0.867              0
# 9361            8.1     6137.0      4.286     1.187              1
# ...             ...        ...        ...       ...            ...
# 6960           15.1     5164.0      3.880     1.779              0
# 6725            7.9     5158.0      3.541     2.995              1
# 8920            8.4     5548.0      3.797     2.113              0
# 7816           10.6     5443.0      4.360     1.008              0
# 8468         2851.3     6350.0      3.921     1.984              0
#
#       koi_fpflag_co  koi_fpflag_ss  koi_fpflag_ec
# 4480              1              0              1
# 4603              0              0              0
# 8971              0              0              0
# 8938              0              1              0
# 9361              0              0              0
# ...             ...            ...            ...
# 6960              0              1              1
# 6725              0              0              0
# 8920              1              0              0
# 7816              0              0              0
# 8468              0              1              0
#
# [7651 rows x 13 columns]

# %%
x_test
# Out:
#       koi_period  koi_impact  koi_duration  koi_depth  koi_prad  \
# 3949  350.810290      0.3892       11.2900      538.3      2.86
# 8695    0.806277      0.6970        7.2750       70.8      0.89
# 2885    2.024144      0.5130        2.5273      239.4      1.94
# 9357    4.173638      0.5970        2.7380       49.7      2.52
# 5052   35.800711      0.0430        8.2190      417.4      7.97
# ...          ...         ...           ...        ...       ...
# 5851    3.490786      0.1160        1.4513      336.8      1.32
# 1075    2.364368      0.1460        3.3720       28.4      0.82
# 7807    0.855747         NaN        2.0100        NaN       NaN
# 1971    2.832647      0.3740        2.3060      114.7      1.37
# 5930   25.643845         NaN        5.0500        NaN       NaN
#
#       koi_model_snr  koi_steff  koi_slogg  koi_srad  koi_fpflag_nt  \
# 3949           15.1     5841.0      4.321     1.226              1
# 8695           37.9     6122.0      4.471     0.996              0
# 2885           88.4     5794.0      4.263     1.225              0
# 9357           10.5     6619.0      3.595     3.410              0
# 5052           25.0     5745.0      3.499     3.955              0
# ...             ...        ...        ...       ...            ...
# 5851           32.7     5496.0      4.618     0.725              0
# 1075           12.4     6250.0      4.184     1.543              0
# 7807            NaN        NaN        NaN       NaN              1
# 1971           27.5     5865.0      4.266     1.272              0
# 5930            NaN        NaN        NaN       NaN              0
#
#       koi_fpflag_co  koi_fpflag_ss  koi_fpflag_ec
# 3949              0              0              0
# 8695              1              1              0
# 2885              0              0              0
# 9357              1              0              0
# 5052              0              0              0
# ...             ...            ...            ...
# 5851              0              0              0
# 1075              0              0              0
# 7807              0              0              0
# 1971              0              0              0
# 5930              0              0              0
#
# [1913 rows x 13 columns]

# %% [markdown]
# ## Train Model

# %%
# number crunch
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators = 250, random_state = 1)
rf.fit(x_train, y_train)

y_train_pred = rf.predict(x_train)
y_test_pred = rf.predict(x_test)

# %% [markdown]
# ## Summary Statistics

# %%
# display data
rf_results = pd.DataFrame([pd.Series(y_test).map({ 1: "Yes", 0: "No"}).reset_index(drop = True), pd.Series(y_test_pred).map({ 1: "Yes", 0: "No"})]).transpose()
rf_results.columns = ["Actual", "Predicted"]

print("Is exoplanet?")
rf_results
# Out:
# Is exoplanet?
#      Actual Predicted
# 0        No        No
# 1        No        No
# 2       Yes       Yes
# 3        No        No
# 4       Yes       Yes
# ...     ...       ...
# 1908    Yes       Yes
# 1909    Yes       Yes
# 1910     No        No
# 1911    Yes       Yes
# 1912     No        No
#
# [1913 rows x 2 columns]

# %%
# final statistics
from sklearn.metrics import roc_auc_score, accuracy_score, f1_score, log_loss

rf_results = pd.DataFrame(["Random Forest Classifier", roc_auc_score(y_test, y_test_pred), accuracy_score(y_test, y_test_pred), f1_score(y_test, y_test_pred)]).transpose()
rf_results.columns = ["Method", "ROC_AUC", "Accuracy", "F-Score"]

rf_results
# Out:
#                      Method  ROC_AUC  Accuracy   F-Score
# 0  Random Forest Classifier  0.99161  0.991636  0.991516

# %% [markdown]
# ## Save Model

# %%
# save to file
import joblib

joblib.dump(rf, "rf_model.pkl")
# Out:
# ['rf_model.pkl']
